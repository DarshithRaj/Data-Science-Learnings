# %% [markdown]
# # EXPLORATORY DATA  ANALYSIS

# %% [markdown]
# # Data Cleaning:

# %%
import pandas as pd
df = pd.read_csv("Cardiotocographic.csv")
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %% [markdown]
# We can see that there are null values in some of the variables that are needed to be handled.

# %%
df.fillna(df.mean(),inplace = True)
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
df.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %% [markdown]
# As all the variables are 'float' datatype i.e a numerical data, so there is no need to change the data type.

# %% [markdown]
# # Statistical summary:

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.214328     0.004370     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001668     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %% [markdown]
# # Observation:

# %% [raw]
# 1.Mean and Median values :we could observe that there is a significant difference between them .That indicates the skewness in the data.
# 2.Standard deviation ,IQR:If std is high that means there is greater variability in the data, if its low is says that the values are clustered around mean.
# While,IQR gives the insight of the spread of central portion of data.
# 3.Min and Max values: As there is large difference between Min and Max, it indicates the presence of outliers that we already found above.

# %% [markdown]
# # Data Visualisation:

# %% [markdown]
# # Histogram:

# %%
# Histogram for a specific column
plt.figure(figsize=(6, 4))
sns.histplot(df['LB'], kde=True)
plt.title('Distribution of Baseline Fetal Heart Rate')
plt.xlabel('Baseline Fetal Heart Rate (LB)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Boxplot:

# %%
plt.figure(figsize=(5, 4))
sns.boxplot(x=df['LB'])
plt.title('Boxplot of Baseline Fetal Heart Rate')
plt.xlabel('Baseline Fetal Heart Rate (LB)')
plt.show()

# %% [markdown]
# # Bargraph:

# %%
sns.barplot(df)
plt.show()

# %% [markdown]
# # Scatter plot between LB and AC:

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(x = 'LB',y = 'AC', data =df)
plt.title('Scatter Plot of Lb vs AC')
plt.xlabel('Baseline Fetal Heart Rate (LB)')
plt.ylabel('Accelerations (AC)')
plt.show()

# %% [markdown]
# # Correlation Analysis:

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Heatmap here is actually not working efficiently on Jupyter ,but its running on Google Collab,I've just verified it.So please consider this assignment.

# %% [markdown]
# # Pair plot for selected variables:

# %% [markdown]
# **A pair plot creates scatter plots for every pair of variables in the dataset, allowing to see how each pair of variables interacts with each other.Scatter plots within the pair plot can highlight outliers in the data by showing points that fall far outside the general distribution.**

# %%
plt.figure(figsize=(4,4))
sns.pairplot(df[['LB', 'AC', 'FM', 'UC']])
plt.show()
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\user\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# # Pattern Recognition and Insights:

# %%
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#                 LB        AC        FM        UC        DL        DS  \
# LB        1.000000 -0.062839  0.018776 -0.166201 -0.126536 -0.005438
# AC       -0.062839  1.000000  0.009432  0.071863 -0.093196 -0.033101
# FM        0.018776  0.009432  1.000000 -0.053226  0.009718  0.029899
# UC       -0.166201  0.071863 -0.053226  1.000000  0.190128 -0.006922
# DL       -0.126536 -0.093196  0.009718  0.190128  1.000000  0.058430
# DS       -0.005438 -0.033101  0.029899 -0.006922  0.058430  1.000000
# DP       -0.047724 -0.083277  0.121274  0.070501  0.144940  0.004285
# ASTV      0.241857 -0.230439 -0.032691 -0.181161 -0.069361  0.008425
# MSTV     -0.169561  0.133649  0.017055  0.189406  0.410102  0.016077
# ALTV      0.210446 -0.271041 -0.011936 -0.227304 -0.186967 -0.004392
# MLTV     -0.003457 -0.104875 -0.006237 -0.049351 -0.165198  0.034349
# Width    -0.118425  0.234735  0.097204  0.107159  0.408664  0.040832
# Tendency  0.236864  0.031977 -0.018338 -0.066463 -0.023490 -0.015398
# ...

# %% [markdown]
# # Conclusion:

# %% [markdown]
# # Key Insights:

# %% [markdown]
# 1. The baseline fetal heart rate (LB) shows a normal distribution with some outliers.
# 2. Accelerations (AC) and baseline fetal heart rate (LB) are positively correlated.
# 3. Significant variations in fetal movements (FM) are observed during uterine contractions (UC).

# %% [markdown]
# # Recommendations:

# %% [markdown]
# - Further investigation into the impact of uterine contractions on fetal well-being is warranted.
# - Consider more sophisticated methods for outlier detection to refine analysis.

# %% [markdown]
# # Further Analysis:

# %% [markdown]
# - Investigate temporal trends in fetal heart rate if time-series data is available.
# - Explore advanced machine learning techniques for predicting fetal distress based on the variables.
